# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

df = pd.read_csv(r'Metro_Interstate_Traffic_Volume.csv')
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0    None  288.28      0.0      0.0          40       Clouds
# 1    None  289.36      0.0      0.0          75       Clouds
# 2    None  289.58      0.0      0.0          90       Clouds
# 3    None  290.13      0.0      0.0          90       Clouds
# 4    None  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
df.describe()
# Out:
#                temp       rain_1h       snow_1h    clouds_all  traffic_volume
# count  48204.000000  48204.000000  48204.000000  48204.000000    48204.000000
# mean     281.205870      0.334264      0.000222     49.362231     3259.818355
# std       13.338232     44.789133      0.008168     39.015750     1986.860670
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%      272.160000      0.000000      0.000000      1.000000     1193.000000
# 50%      282.450000      0.000000      0.000000     64.000000     3380.000000
# 75%      291.806000      0.000000      0.000000     90.000000     4933.000000
# max      310.070000   9831.300000      0.510000    100.000000     7280.000000

# %%
df.drop_duplicates(subset=['date_time'], keep=False, inplace=True)
df.describe()
# Out:
#                temp       rain_1h       snow_1h    clouds_all  traffic_volume
# count  35130.000000  35130.000000  35130.000000  35130.000000    35130.000000
# mean     281.458972      0.316409      0.000012     39.525164     3321.773982
# std       14.227481     52.455921      0.001266     37.798731     1979.627924
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%      271.660000      0.000000      0.000000      1.000000     1315.250000
# 50%      283.280000      0.000000      0.000000     40.000000     3469.500000
# 75%      292.770000      0.000000      0.000000     75.000000     4969.000000
# max      310.070000   9831.300000      0.210000    100.000000     7280.000000

# %%
validate = df['traffic_volume'].tail(10)
df.drop(df['traffic_volume'].tail(10).index,inplace=True)

# %%
uni_data = df['traffic_volume']
uni_data.index = df['date_time']
uni_data = uni_data.values

# %%
##Test Data
test = uni_data[:48]
print(len(uni_data))
uni_data = uni_data[:-48]
print(len(uni_data))
# Out:
# 35120
# 35072

# %%
scaler_x = preprocessing.MinMaxScaler()
x_rescaled = scaler_x.fit_transform(uni_data.reshape(-1, 1))

# %%
def custom_ts_univariate_data_prep(dataset, start, end, window, horizon):
  X = []
  y = []

  start = start + window
  if end is None:
    end = len(dataset) - horizon

  for i in range(start, end):
    indicesx = range(i-window, i)
    X.append(np.reshape(dataset[indicesx], (window, 1)))
    indicesy = range(i,i+horizon)
    y.append(dataset[indicesy])

  return np.array(X), np.array(y)

# %%
x_train_uni, y_train_uni=custom_ts_univariate_data_prep(x_rescaled, 0, 30000, 48, 10)
x_val_uni, y_val_uni=custom_ts_univariate_data_prep(x_rescaled, 30000, None, 48, 10)

# %%
import torch
from torch.utils.data import DataLoader, Dataset, TensorDataset
##Dataset
trainset = TensorDataset(torch.from_numpy(x_train_uni), torch.from_numpy(y_train_uni))
validset = TensorDataset(torch.from_numpy(x_val_uni), torch.from_numpy(y_val_uni))


trainloader = DataLoader(trainset, batch_size=64, shuffle=True, drop_last=True)
validloader = DataLoader(validset, batch_size=64, shuffle=False)

# %%
import torch.nn as nn
import torch
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

##Model
class GRUNet(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, n_layers, drop_prob=0.2):
        super(GRUNet, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        self.gru = nn.GRU(input_dim, hidden_dim, n_layers, batch_first=True, dropout=drop_prob)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        h0 = torch.zeros(self.n_layers, len(x), self.hidden_dim).to(device)
        out, h = self.gru(x,h0.detach())
        out = self.fc(self.relu(out[:,-1]))
        return out, h

# %%
from tqdm import tqdm
import torch.nn.functional as F
import time, sys

##Train

epochs=100
batch_size=256
#output dimension 1->10
model = GRUNet(input_dim=1, hidden_dim=100, output_dim=10, n_layers=2).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
patience = 10

train_log, val_log = [], []
###TRAIN#####
for epoch in range(1, epochs+1):
    start = time.time()
    total_loss, total_num = 0, 0
    model.train()
    
    for x, y in trainloader:  
        x, y = x.cuda(), y.cuda()
        
        y_hat, h = model(x.float())
        loss = criterion(y_hat, y.float().squeeze(-1))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_num += y.shape[0]
        total_loss += loss.item() * y.shape[0]
    train_loss = total_loss/total_num
    train_log.append(train_loss)

    ######VALID######
    model.eval()
    total_loss, total_num = 0, 0
    
    with torch.no_grad():
        for x, y in validloader:  
            x, y = x.cuda(), y.cuda()
            
            y_hat, h = model(x.float())
            
            loss = criterion(y_hat, y.float().squeeze(-1))
     
            total_num += y.shape[0]
            total_loss += loss.item() * y.shape[0]
        valid_loss = total_loss/total_num
    val_log.append(valid_loss)
    time_stamp = (time.time() - start) / 60
    print('Epoch {} train loss: {:.6f} val loss: {:.6f}  - {:.2f} min'.format(epoch, train_loss, valid_loss, time_stamp))
    if np.argmin(val_log[:epoch + 1]) == epoch - 1:
        torch.save(model.state_dict(), "./gru_horizon.pth") 

#     elif np.argmin(val_log[:epoch + 1]) <= epoch -1 - patience:
#         break
# Out:
# Epoch 1 train loss: 0.050005 val loss: 0.029266  - 0.05 min
# Epoch 2 train loss: 0.031902 val loss: 0.027357  - 0.05 min
# Epoch 3 train loss: 0.028495 val loss: 0.025696  - 0.05 min
# Epoch 4 train loss: 0.026711 val loss: 0.024772  - 0.05 min
# Epoch 5 train loss: 0.025438 val loss: 0.023861  - 0.05 min
# Epoch 6 train loss: 0.024657 val loss: 0.023051  - 0.05 min
# Epoch 7 train loss: 0.023950 val loss: 0.022775  - 0.05 min
# Epoch 8 train loss: 0.023492 val loss: 0.023064  - 0.05 min
# Epoch 9 train loss: 0.023041 val loss: 0.022774  - 0.05 min
# Epoch 10 train loss: 0.022565 val loss: 0.022710  - 0.05 min
# Epoch 11 train loss: 0.022173 val loss: 0.022360  - 0.05 min
# Epoch 12 train loss: 0.021836 val loss: 0.022883  - 0.05 min
# Epoch 13 train loss: 0.021346 val loss: 0.023140  - 0.05 min
# Epoch 14 train loss: 0.020952 val loss: 0.023910  - 0.05 min
# Epoch 15 train loss: 0.020619 val loss: 0.022752  - 0.05 min
# Epoch 16 train loss: 0.020111 val loss: 0.023106  - 0.05 min
# Epoch 17 train loss: 0.019677 val loss: 0.022738  - 0.05 min
# Epoch 18 train loss: 0.019307 val loss: 0.023660  - 0.05 min
# Epoch 19 train loss: 0.018727 val loss: 0.023244  - 0.05 min
# Epoch 20 train loss: 0.018272 val loss: 0.024402  - 0.05 min
# Epoch 21 train loss: 0.017822 val loss: 0.023887  - 0.05 min
# Epoch 22 train loss: 0.017362 val loss: 0.024765  - 0.05 min
# Epoch 23 train loss: 0.016961 val loss: 0.024079  - 0.05 min
# Epoch 24 train loss: 0.016476 val loss: 0.024753  - 0.05 min
# Epoch 25 train loss: 0.016129 val loss: 0.025505  - 0.05 min
# Epoch 26 train loss: 0.015659 val loss: 0.026668  - 0.05 min
# Epoch 27 train loss: 0.015355 val loss: 0.026178  - 0.05 min
# Epoch 28 train loss: 0.014973 val loss: 0.026013  - 0.05 min
# Epoch 29 train loss: 0.014731 val loss: 0.025623  - 0.05 min
# Epoch 30 train loss: 0.014279 val loss: 0.025800  - 0.05 min
# Epoch 31 train loss: 0.013976 val loss: 0.026672  - 0.05 min
# Epoch 32 train loss: 0.013710 val loss: 0.027395  - 0.05 min
# Epoch 33 train loss: 0.013358 val loss: 0.027237  - 0.05 min
# Epoch 34 train loss: 0.013273 val loss: 0.027269  - 0.05 min
# Epoch 35 train loss: 0.012972 val loss: 0.027032  - 0.05 min
# Epoch 36 train loss: 0.012712 val loss: 0.028432  - 0.05 min
# Epoch 37 train loss: 0.012552 val loss: 0.028599  - 0.05 min
# Epoch 38 train loss: 0.012383 val loss: 0.027574  - 0.05 min
# Epoch 39 train loss: 0.012083 val loss: 0.029088  - 0.05 min
# Epoch 40 train loss: 0.011929 val loss: 0.028152  - 0.05 min
# Epoch 41 train loss: 0.011707 val loss: 0.029000  - 0.05 min
# Epoch 42 train loss: 0.011608 val loss: 0.029581  - 0.05 min
# Epoch 43 train loss: 0.011381 val loss: 0.028673  - 0.05 min
# Epoch 44 train loss: 0.011240 val loss: 0.028549  - 0.05 min
# Epoch 45 train loss: 0.011039 val loss: 0.029570  - 0.05 min
# Epoch 46 train loss: 0.010945 val loss: 0.029236  - 0.05 min
# Epoch 47 train loss: 0.010874 val loss: 0.029765  - 0.05 min
# Epoch 48 train loss: 0.010658 val loss: 0.030010  - 0.05 min
# Epoch 49 train loss: 0.010446 val loss: 0.029282  - 0.05 min
# Epoch 50 train loss: 0.010346 val loss: 0.030329  - 0.05 min
# Epoch 51 train loss: 0.010184 val loss: 0.029735  - 0.05 min
# Epoch 52 train loss: 0.010065 val loss: 0.030164  - 0.05 min
# Epoch 53 train loss: 0.009996 val loss: 0.030014  - 0.05 min
# Epoch 54 train loss: 0.009803 val loss: 0.029719  - 0.05 min
# Epoch 55 train loss: 0.009758 val loss: 0.029825  - 0.05 min
# Epoch 56 train loss: 0.009674 val loss: 0.031407  - 0.05 min
# Epoch 57 train loss: 0.009540 val loss: 0.030399  - 0.05 min
# Epoch 58 train loss: 0.009459 val loss: 0.031387  - 0.05 min
# Epoch 59 train loss: 0.009305 val loss: 0.031031  - 0.05 min
# Epoch 60 train loss: 0.009162 val loss: 0.031318  - 0.05 min
# Epoch 61 train loss: 0.009258 val loss: 0.032588  - 0.05 min
# Epoch 62 train loss: 0.009022 val loss: 0.031173  - 0.05 min
# Epoch 63 train loss: 0.008956 val loss: 0.030272  - 0.05 min
# Epoch 64 train loss: 0.008846 val loss: 0.032354  - 0.05 min
# Epoch 65 train loss: 0.008800 val loss: 0.033534  - 0.04 min
# Epoch 66 train loss: 0.008740 val loss: 0.031489  - 0.05 min
# Epoch 67 train loss: 0.008761 val loss: 0.031583  - 0.05 min
# Epoch 68 train loss: 0.008542 val loss: 0.032983  - 0.05 min
# Epoch 69 train loss: 0.008390 val loss: 0.030782  - 0.05 min
# Epoch 70 train loss: 0.008485 val loss: 0.032788  - 0.05 min
# Epoch 71 train loss: 0.008225 val loss: 0.033317  - 0.05 min
# Epoch 72 train loss: 0.008234 val loss: 0.033438  - 0.05 min
# Epoch 73 train loss: 0.008310 val loss: 0.032693  - 0.05 min
# Epoch 74 train loss: 0.008042 val loss: 0.032960  - 0.05 min
# Epoch 75 train loss: 0.007960 val loss: 0.034313  - 0.05 min
# Epoch 76 train loss: 0.008031 val loss: 0.031852  - 0.05 min
# Epoch 77 train loss: 0.007919 val loss: 0.032379  - 0.05 min
# Epoch 78 train loss: 0.007827 val loss: 0.034017  - 0.05 min
# Epoch 79 train loss: 0.007786 val loss: 0.034187  - 0.05 min
# Epoch 80 train loss: 0.008136 val loss: 0.033941  - 0.05 min
# Epoch 81 train loss: 0.007617 val loss: 0.032907  - 0.05 min
# Epoch 82 train loss: 0.007597 val loss: 0.032050  - 0.05 min
# Epoch 83 train loss: 0.007430 val loss: 0.031697  - 0.05 min
# Epoch 84 train loss: 0.007678 val loss: 0.033329  - 0.05 min
# Epoch 85 train loss: 0.007436 val loss: 0.034045  - 0.05 min
# Epoch 86 train loss: 0.007515 val loss: 0.032497  - 0.05 min
# Epoch 87 train loss: 0.007293 val loss: 0.033391  - 0.05 min
# Epoch 88 train loss: 0.007231 val loss: 0.033976  - 0.05 min
# Epoch 89 train loss: 0.007100 val loss: 0.032887  - 0.05 min
# Epoch 90 train loss: 0.007082 val loss: 0.032574  - 0.05 min
# Epoch 91 train loss: 0.007199 val loss: 0.033242  - 0.05 min
# Epoch 92 train loss: 0.007268 val loss: 0.032891  - 0.05 min
# Epoch 93 train loss: 0.007014 val loss: 0.031987  - 0.05 min
# Epoch 94 train loss: 0.006880 val loss: 0.033189  - 0.05 min
# Epoch 95 train loss: 0.006838 val loss: 0.033222  - 0.05 min
# Epoch 96 train loss: 0.006910 val loss: 0.033498  - 0.05 min
# Epoch 97 train loss: 0.006903 val loss: 0.033228  - 0.05 min
# Epoch 98 train loss: 0.006934 val loss: 0.033369  - 0.05 min
# Epoch 99 train loss: 0.006894 val loss: 0.032951  - 0.05 min
# Epoch 100 train loss: 0.006651 val loss: 0.033812  - 0.05 min

# %%
#load model
model = GRUNet(1, 100, 10, 2).to(device)
model.load_state_dict(torch.load('./gru_horizon.pth'))

result = []
# Define Forecast length here
window_len = 10
model.eval()
validatehist = uni_data[:48]
val_rescaled = scaler_x.fit_transform(validatehist.reshape(-1, 1))
val_rescaled = torch.from_numpy(val_rescaled).cuda()
val_rescaled = val_rescaled.reshape((1, 48, 1)) #one_batch

Predicted_results, _ = model(val_rescaled.float())
print(f'predicted : {Predicted_results}')
# Out:
# predicted : tensor([[0.7401, 0.7739, 0.8814, 0.9497, 0.8793, 0.7011, 0.5369, 0.4785, 0.4116,
#          0.3323]], device='cuda:0', grad_fn=<AddmmBackward>)

# %%
result_inv_trans = scaler_x.inverse_transform(np.array(Predicted_results.detach().cpu().numpy()).reshape(-1,1))

# %%
result_inv_trans
# Out:
# array([[5244.156 ],
#        [5471.108 ],
#        [6193.6094],
#        [6652.2515],
#        [6179.145 ],
#        [4982.486 ],
#        [3879.234 ],
#        [3486.9805],
#        [3037.8767],
#        [2504.7275]], dtype=float32)

# %%
from sklearn import metrics
def timeseries_evaluation_metrics_func(y_true, y_pred):
    
    def mean_absolute_percentage_error(y_true, y_pred): 
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
timeseries_evaluation_metrics_func(validate, result_inv_trans)
# Out:
# Evaluation metric results:-
# MSE is : 2647089.8985351147
# MAE is : 1540.6573974609375
# RMSE is : 1626.9879835251133
# MAPE is : 102.13421364667903
# R2 is : -0.7185306059517598

# %%
import matplotlib.pyplot as plt
plt.plot(list(validate))
plt.plot(list(result_inv_trans))
plt.title("Actual vs Predicted")
plt.ylabel("Traffic volume")
plt.legend(('Actual','predicted'))
plt.show()
